# %% [markdown]
# # Importing modules

# %%
import pandas as pd
import numpy as np
import re

# %%
#datasets
personality_scores = pd.read_csv('personality_scores.csv', delimiter =';')

# %%
personality_scores.head(5)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
personality_scores.isnull().sum()
# Out:
# ID                                                           0
# Section 5 of 6 [I am always prepared.]                       0
# Section 5 of 6 [I am easily disturbed.]                      0
# Section 5 of 6 [I am exacting (demanding) in my work.]       0
# Section 5 of 6 [I am full of ideas.]                         0
#                                                           ...
# Unnamed: 65                                               1555
# Unnamed: 66                                               1555
# Unnamed: 67                                               1555
# Unnamed: 68                                               1555
# IPIP_HIGH_RISK                                            1555
# Length: 70, dtype: int64

# %% [markdown]
# # Duplicates checking

# %%
unique = personality_scores['ID'].nunique()
unique
# Out:
# 1555

# %% [markdown]
# # Examining the dataframe by ID and droppping duplicates

# %%
personality_new= personality_scores.drop_duplicates(subset = 'ID')

# %% [markdown]
# # checking the new data frame length is = the original data frame

# %%
personality_new['ID'].unique().sum() == personality_scores['ID'].sum()
# Out:
# True

# %% [markdown]
# # Dropping columns with all null values

# %%
personality_scores.dropna(axis = 1, inplace = True)
personality_scores.head(5)
# Out:
#    ID Section 5 of 6 [I am always prepared.]  \
# 0   0                                 (3, 5)
# 1   1                                 (3, 5)
# 2   2                                 (3, 5)
# 3   3                                 (3, 5)
# 4   4                                 (3, 3)
#
#   Section 5 of 6 [I am easily disturbed.]  \
# 0                                  (4, 5)
# 1                                  (4, 5)
# 2                                  (4, 3)
# 3                                  (4, 5)
# 4                                  (4, 5)
#
#   Section 5 of 6 [I am exacting (demanding) in my work.]  \
# 0                                             (3, 5)
# 1                                             (3, 5)
# 2                                             (3, 3)
# 3                                             (3, 3)
# 4                                             (3, 3)
#
#   Section 5 of 6 [I am full of ideas.]  \
# 0                               (5, 5)
# ...

# %%
personality_scores.rename(columns=lambda x: x.replace('Section 5 of 6 [', ''), inplace=True)
personality_scores.rename(columns=lambda x: x.replace('.]',''), inplace=True)
personality_new.rename(columns=lambda x: x.replace(']',''), inplace=True)
personality_new=personality_new.dropna(axis = 1)
personality_new.head(3)
personality_scores.head(5)
# Out:
#    ID I am always prepared I am easily disturbed  \
# 0   0               (3, 5)                (4, 5)
# 1   1               (3, 5)                (4, 5)
# 2   2               (3, 5)                (4, 3)
# 3   3               (3, 5)                (4, 5)
# 4   4               (3, 3)                (4, 5)
#
#   I am exacting (demanding) in my work I am full of ideas  \
# 0                               (3, 5)             (5, 5)
# 1                               (3, 5)             (5, 5)
# 2                               (3, 3)             (5, 5)
# 3                               (3, 3)             (5, 5)
# 4                               (3, 3)             (5, 3)
#
#   I am interested in people I am not interested in abstract ideas  \
# 0                    (2, 3)                                (5, 3)
# 1                    (2, 5)                                (5, 3)
# 2                    (2, 5)                                (5, 5)
# ...

# %% [markdown]
# # Creating new columns

# %%
def score(row, number, dataframe):
    '''Returns a count with
    row = 'row interations
    number = 'Personality it belongs to'
    dataframe = "new dataframe"
    '''
    count = 0
    for column in dataframe.columns:
        breakdown = row[column]
        if type(breakdown) == str:
            tup_break = breakdown[1]
            result = int(breakdown[4])
            if tup_break == number:
                count += result
    return count

#Adding columns the dataframe and applying the score function
personality_new['Extraversion'] = personality_scores.apply(lambda row : score(row,'1', personality_new), axis = "columns")
personality_new['Agreeableness'] = personality_scores.apply(lambda row : score(row,'2', personality_new), axis = "columns")
personality_new['Conscientiousness'] = personality_scores.apply(lambda row : score(row,'3', personality_new), axis = "columns")
personality_new['Emotional stability'] = personality_scores.apply(lambda row : score(row,'4', personality_new), axis = "columns")
personality_new['Intellect'] = personality_scores.apply(lambda row : score(row,'5', personality_new), axis = "columns")

display(personality_scores)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4409             try:
# -> 4410                 return libindex.get_value_at(s, key)
#    4411             except IndexError:
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.get_value_at()
#
# pandas/_libs/util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-007515958a90> in <module>
#      16
#      17 #Adding columns the dataframe and applying the score function
# ...

# %% [markdown]
# # Importing department dataframe

# %%
department_df = pd.read_csv('departments.csv', delimiter =';')
department_df.head(5)

# %%
#ID column to be index of the dataFrame
index = department_df.set_index('ID')
index.head(5)

# %% [markdown]
# # Merging the personality_scores with department_df.

# %%
merging_data = pd.merge(department_df, personality_scores, how='right')
merging_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3b7979d06e6a> in <module>
# ----> 1 merging_data = pd.merge(department_df, personality_scores, how='right')
#       2 merging_data
#
# NameError: name 'department_df' is not defined

# %% [markdown]
# # Create a new data frame with a count of the number of low and high risk applicants within each department

# %%
filtered_high = merging_data[(merging_data.Conscientiousness < 30) & (merging_data.Agreeableness < 30) & (merging_data['Emotional stability'] < 30)]
filtered_high

# %%
merging_data['Risk']=np.where((merging_data.Conscientiousness < 30) & (merging_data.Agreeableness<30) & (merging_data['Emotional stability'] <30),'high_risk','low_risk')
merging_data.head()

# %%
grouped = merging_data["Department"].replace(["Web dev"], "Web Dev", inplace=True)
grouped

# %%
merging_data["Department"].replace(["Web dev"], "Web Dev", inplace=True)

# %%
grouped = merging_data.groupby('Risk')['Department'].value_counts().unstack().fillna(0).astype(int)
grouped

# %%
department_data = pd.DataFrame(grouped.reset_index())
department_data
